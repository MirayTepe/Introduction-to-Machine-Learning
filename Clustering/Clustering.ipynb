# %%
# %pip install scikit-learn
# %pip install matplotlib
# %pip install numpy
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.0.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tepe1\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tepe1\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tepe1\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\tepe1\appdata\local\programs\python\python312\lib\site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
dataset = pd.read_csv("Live.csv")
dataset.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0       0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1       0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2       0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3       0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4       0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
#
#    num_hahas  num_sads  num_angrys  status_type_link  status_type_photo  \
# 0   0.006369  0.019608         0.0               0.0                0.0
# 1   0.000000  0.000000         0.0               0.0                1.0
# 2   0.006369  0.000000         0.0               0.0                0.0
# 3   0.000000  0.000000         0.0               0.0                1.0
# 4   0.000000  0.000000         0.0               0.0                1.0
#
#    status_type_status  status_type_video
# 0                 0.0                1.0
# 1                 0.0                0.0
# 2                 0.0                1.0
# 3                 0.0                0.0
# 4                 0.0                0.0

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3)

# %%
model.fit(dataset)
# Out:
# KMeans(n_clusters=3)

# %%
labels = model.predict(dataset)

# %%
import numpy as np
np.unique(labels, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([2334, 4288,  428]))

# %%
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

silhouettes = []
ks = list(range(2, 12))
for n_cluster in ks:
    kmeans = KMeans(n_clusters=n_cluster).fit(dataset)
    label = kmeans.labels_
    sil_coeff = silhouette_score(dataset, label, metric='euclidean')
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))
    silhouettes.append(sil_coeff)

plt.figure(figsize=(12, 8))    
plt.subplot(211)
plt.scatter(ks, silhouettes, marker='x', c='r')
plt.plot(ks, silhouettes)
plt.xlabel('k')
plt.ylabel('Silhouette score');
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.8100521348183237
# For n_clusters=3, The Silhouette Coefficient is 0.8972493682244883
# For n_clusters=4, The Silhouette Coefficient is 0.8490552719552424
# For n_clusters=5, The Silhouette Coefficient is 0.8866768371183754
# For n_clusters=6, The Silhouette Coefficient is 0.8430118288915796
# For n_clusters=7, The Silhouette Coefficient is 0.7627758034412918
# For n_clusters=8, The Silhouette Coefficient is 0.8419792479641774
# For n_clusters=9, The Silhouette Coefficient is 0.8038319368603519
# For n_clusters=10, The Silhouette Coefficient is 0.7156993695757786
# For n_clusters=11, The Silhouette Coefficient is 0.6887647760221377

# %%
from sklearn.cluster import KMeans
model=KMeans(n_clusters=4)
model.fit(dataset)
labels=model.predict(dataset)
import numpy as np
np.unique(labels, return_counts=True)
# Out:
# (array([0, 1, 2, 3], dtype=int32), array([ 189, 4288, 2145,  428]))

# %%
dataset["labels"] = labels
dataset
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0          0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1          0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2          0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3          0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4          0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
# ...             ...           ...         ...        ...        ...       ...
# 7045       0.018896      0.000000    0.000000   0.018896   0.000000  0.000000
# 7046       0.003397      0.000000    0.000000   0.002972   0.001522  0.000000
# 7047       0.000425      0.000000    0.000000   0.000212   0.001522  0.000000
# 7048       0.074522      0.000572    0.006425   0.074098   0.003044  0.000000
# 7049       0.003609      0.000000    0.000000   0.003609   0.000000  0.000000
#
#       num_hahas  num_sads  num_angrys  status_type_link  status_type_photo  \
# 0      0.006369  0.019608         0.0               0.0                0.0
# 1      0.000000  0.000000         0.0               0.0                1.0
# 2      0.006369  0.000000         0.0               0.0                0.0
# 3      0.000000  0.000000         0.0               0.0                1.0
# 4      0.000000  0.000000         0.0               0.0                1.0
# ...         ...       ...         ...               ...                ...
# 7045   0.000000  0.000000         0.0               0.0                1.0
# 7046   0.006369  0.000000         0.0               0.0                1.0
# 7047   0.000000  0.000000         0.0               0.0                1.0
# 7048   0.000000  0.000000         0.0               0.0                1.0
# 7049   0.000000  0.000000         0.0               0.0                1.0
#
#       status_type_status  status_type_video  labels
# 0                    0.0                1.0       2
# 1                    0.0                0.0       1
# 2                    0.0                1.0       2
# 3                    0.0                0.0       1
# 4                    0.0                0.0       1
# ...                  ...                ...     ...
# 7045                 0.0                0.0       1
# 7046                 0.0                0.0       1
# 7047                 0.0                0.0       1
# 7048                 0.0                0.0       1
# 7049                 0.0                0.0       1
#
# [7050 rows x 14 columns]

# %%
group_zero = dataset[dataset["labels"]==0]["num_comments"].mean()
group_zero
# Out:
# np.float64(0.10733153353448728)

# %%
group_one = dataset[dataset["labels"]==1]["num_comments"].mean()
group_one
# Out:
# np.float64(0.0007619566531325948)

# %%
group_two = dataset[dataset["labels"]==2]["num_comments"].mean()
group_two
# Out:
# np.float64(0.023848585906708793)

# %%
group_three = dataset[dataset["labels"]==3]["num_comments"].mean()
group_three
# Out:
# np.float64(0.0015122911221631663)

# %% [markdown]
# ____

# %%
group_zero = dataset[dataset["labels"]==0]["num_shares"].mean()
group_zero
# Out:
# np.float64(0.13612749097562177)

# %%
group_one = dataset[dataset["labels"]==1]["num_shares"].mean()
group_one
# Out:
# np.float64(0.0007458736181824375)

# %%
group_two = dataset[dataset["labels"]==2]["num_shares"].mean()
group_two
# Out:
# np.float64(0.024767444393612587)

# %%
group_three = dataset[dataset["labels"]==3]["num_shares"].mean()
group_three
# Out:
# np.float64(0.0008263549218272151)

# %%
status_type = dataset[["status_type_photo", "status_type_video", "status_type_status"]].idxmax(axis=1)
dataset = pd.concat([dataset["labels"],status_type.rename("status_type")], axis=1)

# %%
dataset.groupby(["labels","status_type"])["status_type"].count()
# Out:
# labels  status_type
# 0       status_type_video      189
# 1       status_type_photo     4288
# 2       status_type_video     2145
# 3       status_type_photo       63
#         status_type_status     365
# Name: status_type, dtype: int64
